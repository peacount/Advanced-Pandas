# %% [markdown]
# <img src="https://pandas.pydata.org/static/img/pandas.svg" width="250">
#
# ## <center> Pandas Statistical Functions

# %%
import os
os.chdir('C:\\Users\\jenny\\venvs\\py39\\Lib\\site-packages')
import pandas as pd

# %%
iris = pd.read_csv('C:/Users/jenny/venvs/py39/Advanced Pandas/Ex_Files_Adv_Pandas/Exercise Files/iris.csv')
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# ### Measures of Central Tendency

# %%
iris.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris.median()
# Out:
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
iris.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.4          0.2      setosa
# 1           NaN          NaN           1.5          NaN  versicolor
# 2           NaN          NaN           NaN          NaN   virginica

# %% [markdown]
# ### Variance Measures

# %%
iris.std()
# Out:
# sepal_length    0.828066
# sepal_width     0.435866
# petal_length    1.765298
# petal_width     0.762238
# dtype: float64

# %%
iris.boxplot();

# %% [markdown]
# ### Quick insights with `describe()`

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Relationship between variables

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.corr().style.background_gradient(cmap='RdYlGn', axis=None)
# Out:
# <style  type="text/css" >
# #T_126bf_row0_col0,#T_126bf_row1_col1,#T_126bf_row2_col2,#T_126bf_row3_col3{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_126bf_row0_col1,#T_126bf_row1_col0{
#             background-color:  #f57748;
#             color:  #000000;
#         }#T_126bf_row0_col2,#T_126bf_row2_col0{
#             background-color:  #16914d;
#             color:  #000000;
#         }#T_126bf_row0_col3,#T_126bf_row3_col0{
#             background-color:  #2da155;
#             color:  #000000;
#         }#T_126bf_row1_col2,#T_126bf_row2_col1{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_126bf_row1_col3,#T_126bf_row3_col1{
#             background-color:  #bb1526;
#             color:  #f1f1f1;
#         }#T_126bf_row2_col3,#T_126bf_row3_col2{
#             background-color:  #06733d;
#             color:  #f1f1f1;
# ...

# %%
# !pip install Jinja2
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\jenny\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
